# %% [markdown]
# # Introductory loading and visualisation of measurements from Equivital Sensor vest

# %% [markdown]
# ## Prep the notebook

# %%
# !git clone https://github.com/finn42/Beat_Breath_Workshop.git

# %% [markdown]
# Drag the qex.py module into the main folder

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import qex

# %% [markdown]
# ## Locate the demo datasets to be loaded in this notebook
#
# If you have downloaded the demodata2 folder, specify the path to the folder like below. If you are going to downloading files from the internet, you can load the next cell instead.

# %%
demofile_loc = './Beat_Breath_Workshop/demodata/EQ/' #location for colab
df_datafiles = qex.qiosk_recordings(demofile_loc)

# %% [markdown]
# However you are accessing measurements, both should work from here on.
#
# Below shows the information about Equivital measurement files that are extracted by the qex script.

# %%
print(df_datafiles.columns)
df_datafiles
# Out:
# Index(['Signal', 'DevName', 'ID', 'Date', 'Session', 'FileName', 'FileType',
#        'FileSize', 'RecStart', 'RecEnd', 'Duration', 'BatteryStart',
#        'BatteryEnd', 'BatteryChange(mV)', 'FullLoc', 'DATAloc', 'ACCloc',
#        'RESPloc', 'RRloc', 'ECGloc', 'SubjectNames', 'SENSOR ID', 'SUBJECT ID',
#        'HR(BPM)', 'HRC(%)', 'BELT OFF', 'LEAD OFF', 'MOTION', 'BODY POSITION'],
#       dtype='object')
#   Signal DevName       ID    Date  Session                         FileName  \
# 0   DATA   WW501  5022238  241203        4  DATA-WW501-5022238-24120304.CSV
# 1   DATA   LS402  5022204  241203        4  DATA-LS402-5022204-24120304.CSV
# 2   DATA   WW501  5022238  241203        1  DATA-WW501-5022238-24120301.CSV
# 3   DATA   LS402  5022204  241203        1  DATA-LS402-5022204-24120301.CSV
# 4   DATA   WW501  5022238  241203        3  DATA-WW501-5022238-24120303.CSV
# 5   DATA   LS402  5022204  241203        3  DATA-LS402-5022204-24120303.CSV
# 6   DATA   WW501  5022238  241203        2  DATA-WW501-5022238-24120302.CSV
# 7   DATA   LS402  5022204  241203        2  DATA-LS402-5022204-24120302.CSV
#
#   FileType  FileSize                  RecStart                    RecEnd  ...  \
# 0      csv      1816 2024-12-03 14:49:34+00:00 2024-12-03 14:54:19+00:00  ...
# 1      csv      1825 2024-12-03 14:49:35+00:00 2024-12-03 14:54:20+00:00  ...
# 2      csv      2745 2024-12-03 17:29:34+00:00 2024-12-03 17:37:04+00:00  ...
# 3      csv      2717 2024-12-03 17:29:35+00:00 2024-12-03 17:37:05+00:00  ...
# 4      csv      8731 2024-12-03 20:30:04+00:00 2024-12-03 20:55:19+00:00  ...
# 5      csv      8646 2024-12-03 20:30:05+00:00 2024-12-03 20:55:20+00:00  ...
# 6      csv      4912 2024-12-03 20:55:04+00:00 2024-12-03 21:08:49+00:00  ...
# 7      csv      4882 2024-12-03 20:55:05+00:00 2024-12-03 21:08:50+00:00  ...
#
#                                          ECGloc  SubjectNames  SENSOR ID  \
# 0  ./demodata/EQ/ECG-WW501-5022238-24120304.csv       [WW501]  5022238.0
# 1  ./demodata/EQ/ECG-LS402-5022204-24120304.csv       [LS402]  5022204.0
# 2  ./demodata/EQ/ECG-WW501-5022238-24120301.csv       [WW501]  5022238.0
# 3  ./demodata/EQ/ECG-LS402-5022204-24120301.csv       [LS402]  5022204.0
# 4  ./demodata/EQ/ECG-WW501-5022238-24120303.csv       [WW501]  5022238.0
# 5  ./demodata/EQ/ECG-LS402-5022204-24120303.csv       [LS402]  5022204.0
# 6  ./demodata/EQ/ECG-WW501-5022238-24120302.csv       [WW501]  5022238.0
# 7  ./demodata/EQ/ECG-LS402-5022204-24120302.csv       [LS402]  5022204.0
#
#    SUBJECT ID HR(BPM) HRC(%) BELT OFF LEAD OFF        MOTION BODY POSITION
# 0       WW501   240.0   34.0      0.0      1.0    Stationary       Upright
# 1       LS402    77.0   98.0      0.0      0.0  MovingSlowly       Upright
# 2       WW501   131.0   97.0      0.0      0.0    Stationary       Upright
# 3       LS402    77.0   98.0      0.0      0.0    Stationary       Upright
# 4       WW501   101.0   99.0      0.0      0.0    Stationary       Upright
# 5       LS402    77.0   99.0      0.0      0.0    Stationary       Upright
# 6       WW501   122.0   98.0      0.0      0.0  MovingSlowly       Upright
# 7       LS402    82.0   98.0      0.0      0.0  MovingSlowly       Upright
#
# [8 rows x 29 columns]

# %% [markdown]
# ## Load a csv file and look at what kind of values are inside

# %% [markdown]
# Load a csv file of measurements to see their structure, specifying the recording session ID (df_datafiles Index) and the signal file
# location, one of ['DATAloc', 'ACCloc','RESPloc', 'RRloc', 'ECGloc']

# %%
recID = 4
print(df_datafiles.loc[recID,:])
signalFileLoc = 'RESPloc'
V = pd.read_csv(df_datafiles.loc[recID,signalFileLoc])
# Out:
# Signal                                                           DATA
# DevName                                                         WW501
# ID                                                            5022238
# Date                                                           241203
# Session                                                             3
# FileName                              DATA-WW501-5022238-24120303.CSV
# FileType                                                          csv
# FileSize                                                         8731
# RecStart                                    2024-12-03 20:30:04+00:00
# RecEnd                                      2024-12-03 20:55:19+00:00
# Duration                                                       1515.0
# BatteryStart                                                     3982
# BatteryEnd                                                       3977
# BatteryChange(mV)                                                  -5
# FullLoc                 ./demodata/EQ/DATA-WW501-5022238-24120303.CSV
# DATAloc                 ./demodata/EQ/DATA-WW501-5022238-24120303.CSV
# ACCloc               ./demodata/EQ/FASTACC-WW501-5022238-24120303.CSV
# RESPloc              ./demodata/EQ/RESPACC-WW501-5022238-24120303.CSV
# RRloc                     ./demodata/EQ/RR-WW501-5022238-24120303.CSV
# ECGloc                   ./demodata/EQ/ECG-WW501-5022238-24120303.csv
# SubjectNames                                                ['WW501']
# SENSOR ID                                                   5022238.0
# SUBJECT ID                                                      WW501
# HR(BPM)                                                         101.0
# HRC(%)                                                           99.0
# BELT OFF                                                          0.0
# LEAD OFF                                                          0.0
# MOTION                                                     Stationary
# BODY POSITION                                                 Upright
# Name: 4, dtype: object

# %%
V.iloc[:10,:]
# Out:
#                            DateTime  Breathing
# 0  2024-12-03 20:30:03.902000+00:00        501
# 1  2024-12-03 20:30:03.941000+00:00        499
# 2  2024-12-03 20:30:03.980000+00:00        497
# 3  2024-12-03 20:30:04.019000+00:00        496
# 4  2024-12-03 20:30:04.058000+00:00        495
# 5  2024-12-03 20:30:04.097000+00:00        494
# 6  2024-12-03 20:30:04.136000+00:00        492
# 7  2024-12-03 20:30:04.175000+00:00        492
# 8  2024-12-03 20:30:04.214000+00:00        492
# 9  2024-12-03 20:30:04.253000+00:00        492

# %% [markdown]
# The original file specified shows respiration wave measurements ("Breathing") at timestamps specified in UTC Date Time format. You can also load different signal files from the list above.

# %% [markdown]
# ## Plot measurements from a demo session

# %% [markdown]
# Test ploting excerpts of a demo recording by specifying the recording session (df_datafiles Index), the signal type, and the time interval of interest.

# %%
recID = 2
print(df_datafiles.loc[recID,:])
t1 = pd.to_datetime('2024-12-03 17:30:30+00:00')
t2 = pd.to_datetime('2024-12-03 17:35:30+00:00')
t1_cet = t1.tz_convert(tz='Europe/Oslo')
t2_cet = t2.tz_convert(tz='Europe/Oslo')
# Out:
# Signal                                                            DATA
# DevName                                                          WW501
# ID                                                             5022238
# Date                                                            241203
# Session                                                              1
# FileName                               DATA-WW501-5022238-24120301.CSV
# FileType                                                           csv
# FileSize                                                          2745
# RecStart                                     2024-12-03 17:29:34+00:00
# RecEnd                                       2024-12-03 17:37:04+00:00
# Duration                                                         450.0
# BatteryStart                                                      4041
# BatteryEnd                                                        4035
# BatteryChange(mV)                                                   -6
# FullLoc                 ./demodata2/EQ/DATA-WW501-5022238-24120301.CSV
# DATAloc                 ./demodata2/EQ/DATA-WW501-5022238-24120301.CSV
# ACCloc               ./demodata2/EQ/FASTACC-WW501-5022238-24120301.CSV
# RESPloc              ./demodata2/EQ/RESPACC-WW501-5022238-24120301.CSV
# RRloc                     ./demodata2/EQ/RR-WW501-5022238-24120301.CSV
# ECGloc                   ./demodata2/EQ/ECG-WW501-5022238-24120301.csv
# SubjectNames                                                   [WW501]
# SENSOR ID                                                    5022238.0
# SUBJECT ID                                                       WW501
# HR(BPM)                                                          131.0
# HRC(%)                                                            97.0
# BELT OFF                                                           0.0
# LEAD OFF                                                           0.0
# MOTION                                                      Stationary
# BODY POSITION                                                  Upright
# Name: 2, dtype: object

# %% [markdown]
# Plot each of the concurrently measured signal files from this session over the interval of time specified.
#
# Note: if the files are taking too long to load, comment out the lines reading and plotting the largest signals (add a "#" hash at the start of each of the last four lines of code) and rerun the cell.

# %%
# translate the interval of measurement to Central European Time Zone
V = pd.read_csv(df_datafiles.loc[recID,'RESPloc'])
qex.test_plot_signals_interval(V,t1_cet,t2_cet)

V = pd.read_csv(df_datafiles.loc[recID,'RRloc'])
qex.test_plot_signals_interval(V,t1_cet,t2_cet)

V = pd.read_csv(df_datafiles.loc[recID,'ECGloc'])
qex.test_plot_signals_interval(V,t1_cet,t2_cet)

V = pd.read_csv(df_datafiles.loc[recID,'ACCloc'])
qex.test_plot_signals_interval(V,t1_cet,t2_cet)

# %% [markdown]
# Try to look at signals in another session, but with a smaller interval of time.

# %%
recID = 4
print(df_datafiles.loc[recID,:])
t1 = pd.to_datetime('2024-12-03 20:31:15+00:00')
t2 = pd.to_datetime('2024-12-03 20:32:15+00:00')
t1_cet = t1.tz_convert(tz='Europe/Oslo')
t2_cet = t2.tz_convert(tz='Europe/Oslo')
# Out:
# Signal                                                            DATA
# DevName                                                          WW501
# ID                                                             5022238
# Date                                                            241203
# Session                                                              3
# FileName                               DATA-WW501-5022238-24120303.CSV
# FileType                                                           csv
# FileSize                                                          8731
# RecStart                                     2024-12-03 20:30:04+00:00
# RecEnd                                       2024-12-03 20:55:19+00:00
# Duration                                                        1515.0
# BatteryStart                                                      3982
# BatteryEnd                                                        3977
# BatteryChange(mV)                                                   -5
# FullLoc                 ./demodata2/EQ/DATA-WW501-5022238-24120303.CSV
# DATAloc                 ./demodata2/EQ/DATA-WW501-5022238-24120303.CSV
# ACCloc               ./demodata2/EQ/FASTACC-WW501-5022238-24120303.CSV
# RESPloc              ./demodata2/EQ/RESPACC-WW501-5022238-24120303.CSV
# RRloc                     ./demodata2/EQ/RR-WW501-5022238-24120303.CSV
# ECGloc                   ./demodata2/EQ/ECG-WW501-5022238-24120303.csv
# SubjectNames                                                   [WW501]
# SENSOR ID                                                    5022238.0
# SUBJECT ID                                                       WW501
# HR(BPM)                                                          101.0
# HRC(%)                                                            99.0
# BELT OFF                                                           0.0
# LEAD OFF                                                           0.0
# MOTION                                                      Stationary
# BODY POSITION                                                  Upright
# Name: 4, dtype: object

# %%
V = pd.read_csv(df_datafiles.loc[recID,'RESPloc'])
qex.test_plot_signals_interval(V,t1_cet,t2_cet)

V = pd.read_csv(df_datafiles.loc[recID,'RRloc'])
qex.test_plot_signals_interval(V,t1_cet,t2_cet)

V = pd.read_csv(df_datafiles.loc[recID,'ECGloc'])
qex.test_plot_signals_interval(V,t1_cet,t2_cet)

V = pd.read_csv(df_datafiles.loc[recID,'ACCloc'])
qex.test_plot_signals_interval(V,t1_cet,t2_cet)

# %% [markdown]
# Now that you can open and plot individual signals and recordings, check out the Respiration Features and Cardiac Features notebooks to extract more useful information about these systems.
